# %%
import pandas as pd

df_1=pd.read_csv("df_1.csv")
df_2=pd.read_csv("df_2.csv")
df_1
df_2
# Out:
#                                                    App Sentiment  \
# 0                                10 Best Foods for You  Positive
# 1                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive
# 2                                                 11st  Positive
# 3                           1800 Contacts - Lens Store  Positive
# 4                      1LINE – One Line with One Touch  Positive
# ..                                                 ...       ...
# 860  Hotels.com: Book Hotel Rooms & Find Vacation D...  Positive
# 861     Hotspot Shield Free VPN Proxy & Wi-Fi Security  Positive
# 862                                            Hotstar  Negative
# 863                     Hotwire Hotel & Car Rental App  Positive
# 864                     Housing-Real Estate & Property  Negative
#
#      Sentiment_Polarity  Sentiment_Subjectivity
# 0                     0                       0
# 1                     0                       1
# 2                     0                       0
# 3                     0                       1
# 4                     0                       1
# ..                  ...                     ...
# 860                   0                       1
# 861                   0                       0
# 862                   0                       0
# 863                   0                       0
# 864                  -0                       0
#
# [865 rows x 4 columns]

# %%
# Perform outer join
merged_df = pd.merge(df_1, df_2, on='App', how='inner')

# Display the merged DataFrame
merged_df
# Out:
#                                                    App             Category  \
# 0    Canva: Poster, banner, card maker & graphic de...       ART_AND_DESIGN
# 1        Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 2                        Beauty Camera - Selfie Camera               BEAUTY
# 3                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 4                                        Amazon Kindle  BOOKS_AND_REFERENCE
# ..                                                 ...                  ...
# 522                                        Bad Piggies               FAMILY
# 523                      Dumb Ways to Die 2: The Games               FAMILY
# 524                                            AppLock                TOOLS
# 525                     Avakin Life - 3D virtual world               FAMILY
# 526                       A+ Gallery - Photos & Videos          PHOTOGRAPHY
#
#      Rating  Reviews                Size   Installs  Type Price  \
# 0         5   174531                 24M   10000000  Free     0
# 1         4   271920                 16M   10000000  Free     0
# 2         4   113715  Varies with device   10000000  Free     0
# 3         4   814080  Varies with device  100000000  Free     0
# 4         4   814151  Varies with device  100000000  Free     0
# ..      ...      ...                 ...        ...   ...   ...
# 522       4  1168959                 66M   50000000  Free     0
# 523       4  1671658  Varies with device   50000000  Free     0
# 524       4  4931562  Varies with device  100000000  Free     0
# 525       4  1275373                 91M   10000000  Free     0
# 526       4   223941  Varies with device   10000000  Free     0
#
#     Content Rating             Genres    Last Updated         Current Ver  \
# 0         Everyone       Art & Design   July 31, 2018               1.6.1
# 1             Teen    Auto & Vehicles   July 11, 2018  Varies with device
# 2         Everyone             Beauty  August 3, 2017  Varies with device
# 3             Teen  Books & Reference   July 27, 2018  Varies with device
# 4             Teen  Books & Reference   July 27, 2018  Varies with device
# ..             ...                ...             ...                 ...
# 522       Everyone             Puzzle     May 3, 2017               2.3.3
# 523           Teen             Casual   July 12, 2018  Varies with device
# 524       Everyone              Tools   June 11, 2018  Varies with device
# 525           Teen       Role Playing    July 3, 2018            1.021.10
# 526       Everyone        Photography  August 6, 2018  Varies with device
#
#             Android Ver Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0            4.1 and up  Positive                   0                       1
# 1            5.0 and up  Positive                   0                       1
# 2    Varies with device  Positive                   0                       0
# 3    Varies with device  Positive                   0                       0
# 4    Varies with device  Positive                   0                       0
# ..                  ...       ...                 ...                     ...
# 522          4.1 and up  Negative                   0                       1
# 523  Varies with device  Positive                   0                       0
# 524  Varies with device  Negative                   0                       0
# 525          4.1 and up  Positive                   0                       1
# 526  Varies with device  Positive                   0                       0
#
# [527 rows x 16 columns]

# %%
#df.to_csv('reviews.csv', index=True)
merged_df.to_csv('reviews.csv', index=True)
merged_df
# Out:
#                                                    App             Category  \
# 0    Canva: Poster, banner, card maker & graphic de...       ART_AND_DESIGN
# 1        Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 2                        Beauty Camera - Selfie Camera               BEAUTY
# 3                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 4                                        Amazon Kindle  BOOKS_AND_REFERENCE
# ..                                                 ...                  ...
# 522                                        Bad Piggies               FAMILY
# 523                      Dumb Ways to Die 2: The Games               FAMILY
# 524                                            AppLock                TOOLS
# 525                     Avakin Life - 3D virtual world               FAMILY
# 526                       A+ Gallery - Photos & Videos          PHOTOGRAPHY
#
#      Rating  Reviews                Size   Installs  Type Price  \
# 0         5   174531                 24M   10000000  Free     0
# 1         4   271920                 16M   10000000  Free     0
# 2         4   113715  Varies with device   10000000  Free     0
# 3         4   814080  Varies with device  100000000  Free     0
# 4         4   814151  Varies with device  100000000  Free     0
# ..      ...      ...                 ...        ...   ...   ...
# 522       4  1168959                 66M   50000000  Free     0
# 523       4  1671658  Varies with device   50000000  Free     0
# 524       4  4931562  Varies with device  100000000  Free     0
# 525       4  1275373                 91M   10000000  Free     0
# 526       4   223941  Varies with device   10000000  Free     0
#
#     Content Rating             Genres    Last Updated         Current Ver  \
# 0         Everyone       Art & Design   July 31, 2018               1.6.1
# 1             Teen    Auto & Vehicles   July 11, 2018  Varies with device
# 2         Everyone             Beauty  August 3, 2017  Varies with device
# 3             Teen  Books & Reference   July 27, 2018  Varies with device
# 4             Teen  Books & Reference   July 27, 2018  Varies with device
# ..             ...                ...             ...                 ...
# 522       Everyone             Puzzle     May 3, 2017               2.3.3
# 523           Teen             Casual   July 12, 2018  Varies with device
# 524       Everyone              Tools   June 11, 2018  Varies with device
# 525           Teen       Role Playing    July 3, 2018            1.021.10
# 526       Everyone        Photography  August 6, 2018  Varies with device
#
#             Android Ver Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0            4.1 and up  Positive                   0                       1
# 1            5.0 and up  Positive                   0                       1
# 2    Varies with device  Positive                   0                       0
# 3    Varies with device  Positive                   0                       0
# 4    Varies with device  Positive                   0                       0
# ..                  ...       ...                 ...                     ...
# 522          4.1 and up  Negative                   0                       1
# 523  Varies with device  Positive                   0                       0
# 524  Varies with device  Negative                   0                       0
# 525          4.1 and up  Positive                   0                       1
# 526  Varies with device  Positive                   0                       0
#
# [527 rows x 16 columns]

# %%
merged_df[['Category','Reviews']].sort_values(by=['Reviews'], ascending=False).head(12)

#df.sort_values(by=['col1'])
# Out:
#     Category   Reviews
# 290   SOCIAL  78158306
# 291   SOCIAL  78128208
# 149     GAME  44893888
# 148     GAME  44891723
# 147     GAME  44891723
# 150   FAMILY  44881447
# 132     GAME  23136735
# 131     GAME  23134775
# 130     GAME  23133508
# 133   FAMILY  23125280
# 122     GAME  22430188
# 121     GAME  22430188

# %%
 merged_df[['Category', 'Reviews']].groupby('Category').sum('Reviews').sort_values(by=['Reviews'], ascending=False).head(12)
# Out:
#                     Reviews
# Category
# GAME              722151242
# SOCIAL            201988251
# FAMILY            158694992
# PHOTOGRAPHY       100452572
# TOOLS              80792195
# COMMUNICATION      79885520
# SHOPPING           45149481
# PERSONALIZATION    31159946
# SPORTS             29201694
# PRODUCTIVITY       27417883
# EDUCATION          25361503
# TRAVEL_AND_LOCAL   19069134

# %%
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 merged_df
#
# NameError: name 'merged_df' is not defined

# %%
pd.options.display.float_format = '{:,.0f}'.format
grouped_df = merged_df[['Category', 'Reviews']].groupby('Category').mean().sort_values(by=['Reviews'], ascending=False)
grouped_df
# Out:
#                        Reviews
# Category
# GAME                 722151242
# SOCIAL               201988251
# FAMILY               158694992
# PHOTOGRAPHY          100452572
# TOOLS                 80792195
# COMMUNICATION         79885520
# SHOPPING              45149481
# PERSONALIZATION       31159946
# SPORTS                29201694
# PRODUCTIVITY          27417883
# EDUCATION             25361503
# TRAVEL_AND_LOCAL      19069134
# HEALTH_AND_FITNESS    12356102
# NEWS_AND_MAGAZINES    10142503
# ENTERTAINMENT          8072882
# WEATHER                5550823
# BOOKS_AND_REFERENCE    5435185
# FINANCE                5435005
# BUSINESS               3417123
# FOOD_AND_DRINK         2681399
# LIFESTYLE              2447250
# DATING                  514788
# AUTO_AND_VEHICLES       271920
# ART_AND_DESIGN          174531
# LIBRARIES_AND_DEMO      126862
# BEAUTY                  113715
# VIDEO_PLAYERS            45744

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Grouped by 'Category' , summed by reviews
grouped_df = merged_df[['Category', 'Reviews']].groupby('Category').sum().sort_values(by='Reviews', ascending=False)

grouped_df = grouped_df.reset_index()

top_15_df = grouped_df.head(15)

plt.figure(figsize=(10, 8))

sns.barplot(x='Category', y='Reviews', data=top_15_df, palette="Blues_d")


plt.xticks(rotation=45, ha='right')

plt.title("Top 15 categories by number of reviews")
plt.xlabel("Category")
plt.ylabel("Number of reviews")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Grouped by 'Category' , summed by reviews
grouped_df = merged_df[['Category', 'Reviews']].groupby('Category').sum().sort_values(by='Reviews', ascending=False)

grouped_df = grouped_df.reset_index()

top_15_df = grouped_df.head(15)

plt.figure(figsize=(10, 8))

sns.barplot(x='Category', y='Reviews', data=top_15_df, palette="Blues_d")


plt.xticks(rotation=45, ha='right')

plt.title("Top 15 categories by number of reviews")
plt.xlabel("Category")
plt.ylabel("Number of reviews")

plt.show()
