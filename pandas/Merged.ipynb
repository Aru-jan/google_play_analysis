# %%
import pandas as pd

df_1=pd.read_csv("C:/Users/ngaut/Downloads/df_1.csv")
df_2=pd.read_csv("C:/Users/ngaut/Downloads/df_2.csv")
df_1
# Out:
#                                                     App            Category  \
# 0                                 Sketch - Draw & Paint      ART_AND_DESIGN
# 1                        Tattoo Name On My Photo Editor      ART_AND_DESIGN
# 2                                          ibis Paint X      ART_AND_DESIGN
# 3                            Textgram - write on photos      ART_AND_DESIGN
# 4     Canva: Poster, banner, card maker & graphic de...      ART_AND_DESIGN
# ...                                                 ...                 ...
# 2075                            MX Player Codec (ARMv7)  LIBRARIES_AND_DEMO
# 2076                                         PhotoFunia         PHOTOGRAPHY
# 2077                               Modern Strike Online                GAME
# 2078                                         Big Hunter                GAME
# 2079      iHoroscope - 2018 Daily Horoscope & Astrology           LIFESTYLE
#
# ...

# %%
df_2
# Out:
#                                                    App Sentiment  \
# 0                                10 Best Foods for You  Positive
# 1                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive
# 2                                                 11st  Positive
# 3                           1800 Contacts - Lens Store  Positive
# 4                      1LINE – One Line with One Touch  Positive
# ..                                                 ...       ...
# 860  Hotels.com: Book Hotel Rooms & Find Vacation D...  Positive
# 861     Hotspot Shield Free VPN Proxy & Wi-Fi Security  Positive
# 862                                            Hotstar  Negative
# 863                     Hotwire Hotel & Car Rental App  Positive
# 864                     Housing-Real Estate & Property  Negative
#
#      Sentiment_Polarity  Sentiment_Subjectivity
# 0              0.470733                0.495455
# 1              0.392405                0.545516
# ...

# %%
# Perform outer join
merged_df = pd.merge(df_1, df_2, on='App', how='inner')

# Display the merged DataFrame
merged_df
# Out:
#                                                    App             Category  \
# 0    Canva: Poster, banner, card maker & graphic de...       ART_AND_DESIGN
# 1        Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 2                        Beauty Camera - Selfie Camera               BEAUTY
# 3                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 4                                          Cool Reader  BOOKS_AND_REFERENCE
# ..                                                 ...                  ...
# 522                                   Farm Heroes Saga               FAMILY
# 523                                    Fallout Shelter               FAMILY
# 524                             Facebook Pages Manager             BUSINESS
# 525                                   Garena Free Fire                 GAME
# 526                         Fun Kid Racing - Motocross               FAMILY
#
# ...

# %%
df.to_csv('C:/Users/ngaut/Documents/Ironhack/Week4/Project/archive/reviews.csv', index=True)
